# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = [1,5,3,8,2,4]
#y = ["a", "b", "a", "a", "b", "d"]

# %%
#plt.plot(np.random.rand(20))
#fig = plt.figure()
plt.plot(x)

plt.title('test title')
plt.show()
